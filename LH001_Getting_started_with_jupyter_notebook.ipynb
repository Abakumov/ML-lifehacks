# %% [markdown]
# # How to get started with JupyterLab
#
# 23.10.2019
# Berlin
#
# What will change tomorrow? Let's see...
#
# **Start with these useful references:**
# - How to install JupyterLab on Windows 10 laptop?
#
# https://mycarta.wordpress.com/2019/07/09/from-zero-to-jupyterlab-pro-on-windows-10/
#
# - About JupyterLab interface
#
# https://jupyterlab.readthedocs.io/en/stable/user/interface.html
#
# - About Jupyter Notebooks
#
# https://jupyterlab.readthedocs.io/en/stable/user/notebook.html
#
# - Basics of Jupyter Labs:
#
# https://www.youtube.com/watch?v=Gzun8PpyBCo
#
# https://www.youtube.com/watch?v=a9P7qv4P5LE

# %%
a = 2
b = 3
c = a + b
print(c)
# Out:
# 5

# %% [markdown]
# # Add formulas with LaTeX
#
# Example: Maxwell's equations in the vacuum
#
# \begin{align}
#   \nabla \cdot \mathbf{E} &= 0 \quad & \nabla \times \mathbf{E} &= -\frac{\partial\mathbf B}{\partial t}, \\
#   \nabla \cdot \mathbf{B} &= 0 \quad & \nabla \times \mathbf{B} &= \mu_0\varepsilon_0 \frac{\partial\mathbf E}{\partial t}.
# \end{align}

# %% [markdown]
# # How to include image/figure in the notebook
#
# **Quick tutorial**
#
# https://www.youtube.com/watch?v=xlD8FIM5biA

# %% [markdown]
# **Method 1: Add figure to the text**
#
# ![title](figures/LH001_1.jpg)

# %% [markdown]
# **Method 2: Add Figure with Image class**

# %%
from IPython.display import Image
Image(filename="figures/LH001_1.jpg",width=400,height=400)
